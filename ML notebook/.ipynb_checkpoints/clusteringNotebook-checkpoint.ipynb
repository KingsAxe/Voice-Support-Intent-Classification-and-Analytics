# %% [markdown]
# #### **Overview**

# %% [markdown]
# **Steps:**
# 1. Select clustering features
# 2. Clean + impute missing values
# 3. Scale numeric columns
# 4. One-hot encode categorical columns
# 5. Vectorize topics
# 6. Combine features
# 7. Apply clustering (KMeans / GMM / HDBSCAN)

# %%
# pip install hdbscan scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.mixture import GaussianMixture
import hdbscan

# %%
df_copy = pd.read_csv(r"C:\Users\pc\Desktop\Pro_Jets\CC EDA&ML\EDA notebook\df_copy.csv")
df_copy.head()
# Out:
#   interaction_id customer_id agent_id interaction_datetime  \
# 0       INT00001   CUST00001  AGT0001  2024-01-01 09:10:13
# 1       INT00002   CUST00002  AGT0002  2024-01-01 11:24:50
# 2       INT00003   CUST00003  AGT0003  2024-01-01 13:32:05
# 3       INT00004   CUST00001  AGT0004  2024-01-02 10:45:14
# 4       INT00005   CUST00004  AGT0001  2024-01-02 15:08:55
#
#    interaction_duration_seconds call_direction call_channel call_status  \
# 0                           415        inbound        phone   completed
# 1                            23       outbound        phone     dropped
# 2                           198        inbound         chat   completed
# 3                            37        inbound        phone   abandoned
# 4                           720        inbound        phone   completed
#
#    customer_satisfaction_score  speech_sentiment_score  ... issue_resolved  \
# 0                          4.7                    0.82  ...           True
# 1                          NaN                     NaN  ...          False
# 2                          4.1                    0.63  ...           True
# 3                          0.0                   -0.95  ...          False
# 4                          4.5                    0.91  ...           True
#
#   follow_up_required  follow_up_due_date  language  \
# 0              False                 NaN        en
# 1              False                 NaN        en
# 2              False                 NaN        es
# 3              False                 NaN        en
# 4              False                 NaN        en
#
#                     customer_feedback_text  \
# 0  Thank you for your help, great service.
# 1                                      NaN
# 2                      Gracias, todo bien.
# 3                                      NaN
# 4               Resolved my issue quickly.
#
#                                          agent_notes call_hour call_dayofweek  \
# 0  Customer called regarding password reset. Issu...         9         Monday
# 1      Call dropped instantly. No customer response.        11         Monday
# 2  Customer requested recent statements. Provided...        13         Monday
# 3  Caller disconnected before an agent could answer.        10        Tuesday
# 4  Customer reported card decline online. Walked ...        15        Tuesday
#
#    csat_band hour
# 0        4-5    9
# 1        NaN   11
# 2        4-5   13
# 3        NaN   10
# 4        4-5   15
#
# [5 rows x 22 columns]

# %% [markdown]
# #### **Clustering Pipeline**

# %%
# ---- select features ----
num_features = [
    "interaction_duration_seconds",
    "speech_sentiment_score",
    "customer_satisfaction_score",
    "call_hour"
]

cat_features = [
    "call_direction",
    "call_channel",
    "call_dayofweek",
    "issue_resolved",
    "follow_up_required"
]

df_model = df_copy[num_features + cat_features].copy()

# %%
# ---- preprocessing ----
preprocessor = ColumnTransformer(
    [
        ("num", StandardScaler(), num_features),
        ("cat", OneHotEncoder(handle_unknown="ignore"), cat_features)
    ]
)

X = preprocessor.fit_transform(df_model)

# %%
# ---- HDBSCAN base clustering ----
hdb = hdbscan.HDBSCAN(
    min_cluster_size=10,
    min_samples=5,
    metric="euclidean",
    prediction_data=True
).fit(X)

df_copy["hdbscan_cluster"] = hdb.labels_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 7
#       1 # ---- HDBSCAN base clustering ----
#       2 hdb = hdbscan.HDBSCAN(
#       3     min_cluster_size=10,
#       4     min_samples=5,
#       5     metric="euclidean",
#       6     prediction_data=True
# ----> 7 ).fit(X)
#       9 df_copy["hdbscan_cluster"] = hdb.labels_
#
# File ~\anaconda3\Lib\site-packages\hdbscan\hdbscan_.py:1291, in HDBSCAN.fit(self, X, y)
#    1288     self.probabilities_ = new_probabilities
#    1290 if self.prediction_data:
# -> 1291     self.generate_prediction_data()
#    1292 if self.branch_detection_data:
#    1293     self.generate_branch_detection_data()
#
# File ~\anaconda3\Lib\site-packages\hdbscan\hdbscan_.py:1332, in HDBSCAN.generate_prediction_data(self)
#    1329         warn("Metric {} not supported for prediction data!".format(self.metric))
#    1330         return
# -> 1332     self._prediction_data = PredictionData(
#    1333         self._raw_data,
#    1334         self.condensed_tree_,
#    1335         min_samples,
#    1336         tree_type=tree_type,
#    1337         metric=self.metric,
#    1338         **self._metric_kwargs
#    1339     )
#    1340 else:
#    1341     warn(
#    1342         "Cannot generate prediction data for non-vector "
#    1343         "space inputs -- access to the source data rather "
#    1344         "than mere distances is required!"
#    1345     )
#
# File ~\anaconda3\Lib\site-packages\hdbscan\prediction.py:101, in PredictionData.__init__(self, data, condensed_tree, min_samples, tree_type, metric, **kwargs)
#      98 def __init__(self, data, condensed_tree, min_samples,
#      99              tree_type='kdtree', metric='euclidean', **kwargs):
#     100     self.raw_data = data.astype(np.float64)
# --> 101     self.tree = self._tree_type_map[tree_type](self.raw_data,
#     102                                                metric=metric, **kwargs)
#     103     self.core_distances = self.tree.query(data, k=min_samples)[0][:, -1]
#     104     self.dist_metric = DistanceMetric.get_metric(metric, **kwargs)
#
# File sklearn\\neighbors\\_binary_tree.pxi:893, in sklearn.neighbors._kd_tree.BinaryTree64.__init__()
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1107, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, force_all_finite, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1101     raise ValueError(
#    1102         "Found array with dim %d. %s expected <= 2."
#    1103         % (array.ndim, estimator_name)
#    1104     )
#    1106 if ensure_all_finite:
# -> 1107     _assert_all_finite(
#    1108         array,
#    1109         input_name=input_name,
#    1110         estimator_name=estimator_name,
#    1111         allow_nan=ensure_all_finite == "allow-nan",
#    1112     )
#    1114 if copy:
#    1115     if _is_numpy_namespace(xp):
#    1116         # only make a copy if `array` and `array_orig` may share memory`
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:120, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     117 if first_pass_isfinite:
#     118     return
# --> 120 _assert_all_finite_element_wise(
#     121     X,
#     122     xp=xp,
#     123     allow_nan=allow_nan,
#     124     msg_dtype=msg_dtype,
#     125     estimator_name=estimator_name,
#     126     input_name=input_name,
#     127 )
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:169, in _assert_all_finite_element_wise(X, xp, allow_nan, msg_dtype, estimator_name, input_name)
#     152 if estimator_name and input_name == "X" and has_nan_error:
#     153     # Improve the error message on how to handle missing values in
#     154     # scikit-learn.
#     155     msg_err += (
#     156         f"\n{estimator_name} does not accept missing values"
#     157         " encoded as NaN natively. For supervised learning, you might want"
#    (...)
#     167         "#estimators-that-handle-nan-values"
#     168     )
# --> 169 raise ValueError(msg_err)
#
# ValueError: Input contains NaN.

# %%
# ---- Gaussian Mixture refinement ----
valid_idx = df_copy["hdbscan_cluster"] != -1
X_valid = X[valid_idx]

gmm = GaussianMixture(
    n_components=4,
    covariance_type="full",
    random_state=42
).fit(X_valid)

df_copy["gmm_cluster"] = -1
df_copy.loc[valid_idx, "gmm_cluster"] = gmm.predict(X_valid)

# ---- SOFT CLUSTER PROBABILITY ----
probs = np.full((len(df_copy), 4), np.nan)
probs[valid_idx] = gmm.predict_proba(X_valid)

for i in range(4):
    df_copy[f"gmm_prob_{i}"] = probs[:, i]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hdbscan_cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 2
#       1 # ---- Gaussian Mixture refinement ----
# ----> 2 valid_idx = df_copy["hdbscan_cluster"] != -1
#       3 X_valid = X[valid_idx]
#       5 gmm = GaussianMixture(
#       6     n_components=4,
#       7     covariance_type="full",
#       8     random_state=42
#       9 ).fit(X_valid)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'hdbscan_cluster'
